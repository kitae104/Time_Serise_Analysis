# %% [markdown]
# # Pandas 소개
#
# 이 과정의 이 섹션에서는 데이터 분석을 위해 pandas를 사용하는 방법을 배웁니다. pandas는 훨씬 더 많은 기능을 갖춘 매우 강력한 Excel의 확장판이라고 생각할 수 있습니다. 이 섹션에서는 아래 순서대로 노트북을 진행하면 됩니다:
#
# * Pandas 소개
# * Series
# * DataFrames
# * 결측치
# * GroupBy
# * 병합, 조인, 연결
# * 연산
# * 데이터 입력과 출력

# %% [markdown]
# ___
